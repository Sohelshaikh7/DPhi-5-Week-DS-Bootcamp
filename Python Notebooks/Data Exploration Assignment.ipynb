# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('/Standard Metropolitan Areas Data - train_data - data.csv')

# %%
data.head()
# Out:
#    land_area  percent_city  percent_senior  ...  income  region  crime_rate
# 0       1384          78.1            12.3  ...   72100       1       75.55
# 1       3719          43.9             9.4  ...   54542       2       56.03
# 2       3553          37.4            10.7  ...   33216       1       41.32
# 3       3916          29.9             8.8  ...   32906       2       67.38
# 4       2480          31.5            10.5  ...   26573       4       80.19
#
# [5 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   land_area       99 non-null     int64
#  1   percent_city    99 non-null     float64
#  2   percent_senior  99 non-null     float64
#  3   physicians      99 non-null     int64
#  4   hospital_beds   99 non-null     int64
#  5   graduates       99 non-null     float64
#  6   work_force      99 non-null     float64
#  7   income          99 non-null     int64
#  8   region          99 non-null     int64
#  9   crime_rate      99 non-null     float64
# dtypes: float64(5), int64(5)
# memory usage: 7.9 KB

# %%
data.mean()
# Out:
# land_area         2615.727273
# percent_city        42.518182
# percent_senior       9.781818
# physicians        1828.333333
# hospital_beds     6345.868687
# graduates           54.463636
# work_force         449.366667
# income            6762.505051
# region               2.494949
# crime_rate          55.643030
# dtype: float64

# %%
data.max()
# Out:
# land_area         27293.00
# percent_city        100.00
# percent_senior       21.80
# physicians        25627.00
# hospital_beds     69678.00
# graduates            72.80
# work_force         4083.90
# income            72100.00
# region                4.00
# crime_rate           85.62
# dtype: float64

# %%
data.min()
# Out:
# land_area          47.00
# percent_city       13.40
# percent_senior      3.90
# physicians        140.00
# hospital_beds     481.00
# graduates          30.30
# work_force         66.90
# income            769.00
# region              1.00
# crime_rate         23.32
# dtype: float64

# %%
data['region'].value_counts()
# Out:
# 3    36
# 2    25
# 1    21
# 4    17
# Name: region, dtype: int64

# %%
data.isnull().sum()
# Out:
# land_area         0
# percent_city      0
# percent_senior    0
# physicians        0
# hospital_beds     0
# graduates         0
# work_force        0
# income            0
# region            0
# crime_rate        0
# dtype: int64

# %%
data.corr()
# Out:
#                 land_area  percent_city  ...    region  crime_rate
# land_area        1.000000     -0.077320  ...  0.292392    0.293907
# percent_city    -0.077320      1.000000  ...  0.235880    0.159596
# percent_senior   0.092226     -0.250995  ... -0.242811   -0.177992
# physicians       0.085054      0.067391  ... -0.140961    0.187763
# hospital_beds    0.081034      0.052898  ... -0.220305    0.109799
# graduates        0.088728      0.076720  ...  0.246226    0.290880
# work_force       0.135792      0.016011  ... -0.144022    0.175945
# income           0.111404      0.019235  ... -0.152016    0.175797
# region           0.292392      0.235880  ...  1.000000    0.636192
# crime_rate       0.293907      0.159596  ...  0.636192    1.000000
#
# [10 rows x 10 columns]

# %%
data[data['region']==4].head()
# Out:
#     land_area  percent_city  percent_senior  ...  income  region  crime_rate
# 4        2480          31.5            10.5  ...   26573       4       80.19
# 13        782          28.4             7.8  ...   12591       4       63.20
# 14       4226          38.1             9.8  ...   10918       4       64.05
# 18      27293          25.3            12.3  ...    7399       4       76.03
# 20       9155          53.8            11.1  ...    7766       4       85.62
#
# [5 rows x 10 columns]

# %%
data[data['crime_rate']== 85.62]
# Out:
#     land_area  percent_city  percent_senior  ...  income  region  crime_rate
# 20       9155          53.8            11.1  ...    7766       4       85.62
#
# [1 rows x 10 columns]

# %%
data[(data['region']== 1) & (data['crime_rate']>= 54.16)]
# Out:
#     land_area  percent_city  percent_senior  ...  income  region  crime_rate
# 0        1384          78.1            12.3  ...   72100       1       75.55
# 10       1008          16.6            10.3  ...   15953       1       54.16
# 24       2966          26.9            10.3  ...    6966       1       56.55
# 55        192          60.5            10.8  ...    3158       1       58.79
#
# [4 rows x 10 columns]

# %%
data[(data['region']== 3) | (data['land_area']>= 5000)].count()
# Out:
# land_area         41
# percent_city      41
# percent_senior    41
# physicians        41
# hospital_beds     41
# graduates         41
# work_force        41
# income            41
# region            41
# crime_rate        41
# dtype: int64

# %%
data[(data['region']== 4) & (data['crime_rate']== 55.64)]
# Out:
# Empty DataFrame
# Columns: [land_area, percent_city, percent_senior, physicians, hospital_beds, graduates, work_force, income, region, crime_rate]
# Index: []

# %%
plt.plot('land_area','crime_rate',data= data)

# %%
sns.scatterplot('physicians','hospital_beds',data= data)

# %%
data['region'].value_counts().plot(kind='bar')

# %%
plt.hist('income',data= data)
# Out:
# (array([80.,  9.,  4.,  2.,  2.,  0.,  0.,  1.,  0.,  1.]),
#  array([  769. ,  7902.1, 15035.2, 22168.3, 29301.4, 36434.5, 43567.6,
#         50700.7, 57833.8, 64966.9, 72100. ]),
#  <a list of 10 Patch objects>)
